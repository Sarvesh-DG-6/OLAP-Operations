# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objs as go
from IPython.display import display

# %%
swiggy_df = pd.read_csv('/content/swiggy.csv')

# %%
display(swiggy_df)
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# 0     300.0          4.4            100
# 1     300.0          4.1            100
# 2     650.0          4.4            100
# 3     250.0          3.9            500
# 4     350.0          4.0             50
# ...     ...          ...            ...
# 8675  500.0          2.9             80
# 8676  200.0          2.9             80
# 8677  150.0          2.9             80
# 8678  150.0          2.9             80
# 8679  250.0          2.9             80
#
#                                               Food type       Address  \
# 0             Biryani,Chinese,North Indian,South Indian     5Th Block
# 1                                      Mughlai,Lucknowi     5Th Block
# 2                                               Chinese   Double Road
# 3                  North Indian,Punjabi,Tandoor,Chinese  80 Feet Road
# 4     Rajasthani,Gujarati,North Indian,Snacks,Desser...  80 Feet Road
# ...                                                 ...           ...
# 8675                                             Pizzas   Navrangpura
# 8676                                       South Indian        Rohini
# 8677                             Chinese,Snacks,Tandoor        Rohini
# 8678                         North Indian,Indian,Snacks        Rohini
# 8679                               Chaat,Snacks,Chinese   Navrangpura
#
#       Delivery time
# 0                59
# 1                56
# 2                50
# 3                57
# 4                63
# ...             ...
# 8675             40
# 8676             28
# 8677             58
# 8678             28
# 8679             44
#
# [8680 rows x 10 columns]

# %%
# 3D scatter plot to visualize the original data
fig_original = px.scatter_3d(swiggy_df, x='Price', y='Avg ratings', z='Delivery time', color='City', title='3D Visualization of Swiggy Data')
fig_original.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f5b874ab-a006-4233-a63a-f454cf112eca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5b874ab-a006-4233-a63a-f454cf112eca")) {                    Plotly.newPlot(                        "f5b874ab-a006-4233-a63a-f454cf112eca",                        [{"hovertemplate":"City=Bangalore\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bangalore","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Bangalore","scene":"scene","showlegend":true,"x":[300.0,300.0,650.0,250.0,350.0,800.0,1000.0,150.0,350.0,300.0,400.0,250.0,532.0,500.0,150.0,290.0,300.0,250.0,800.0,1200.0,250.0,900.0,200.0,250.0,300.0,300.0,500.0,450.0,300.0,1000.0,300.0,550.0,450.0,200.0,300.0,200.0,400.0,500.0,450.0,500.0,500.0,1100.0,200.0,326.0,250.0,150.0,850.0,600.0,600.0,800.0,300.0,1100.0,500.0,400.0,200.0,200.0,250.0,1400.0,450.0,450.0,300.0,300.0,1000.0,400.0,400.0,800.0,600.0,1500.0,800.0,300.0,400.0,200.0,500.0,800.0,400.0,500.0,299.0,400.0,200.0,200.0,599.0,500.0,300.0,500.0,500.0,600.0,900.0,450.0,1400.0,600.0,400.0,1100.0,450.0,400.0,400.0,400.0,193.0,1300.0,1000.0,450.0,700.0,200.0,499.0,250.0,400.0,600.0,600.0,300.0,300.0,700.0,1200.0,200.0,300.0,350.0,300.0,150.0,178.0,500.0,350.0,300.0,1300.0,1000.0,400.0,700.0,500.0,600.0,600.0,250.0,1000.0,400.0,450.0,250.0,300.0,500.0,330.0,600.0,750.0,400.0,400.0,800.0,350.0,500.0,800.0,1000.0,250.0,500.0,178.0,800.0,300.0,450.0,200.0,50.0,250.0,500.0,350.0,300.0,400.0,250.0,200.0,300.0,
display("Roll-up operation result:\n", roll_up_swiggy)
# Out:
# 'Roll-up operation result:\n'
#         City       Price  Avg ratings  Delivery time
# 0  Ahmedabad  318.128312     3.596513      44.709902
# 1  Bangalore  382.524313     3.762896      50.529598
# 2    Chennai  356.247740     3.776311      58.968354
# 3      Delhi  333.301146     3.526350      50.734861
# 4  Hyderabad  299.926512     3.701395      49.933023
# 5    Kolkata  362.294205     3.698811      67.809807
# 6     Mumbai  393.794832     3.599374      48.318716
# 7       Pune  353.763303     3.550183      55.854128
# 8      Surat  270.171875     3.580078      48.484375

# %%
# 3D scatter plot to visualize the roll-up data
fig_rollup = px.scatter_3d(roll_up_swiggy, x='City', y='Price', z='Delivery time', color='Avg ratings', title='3D Visualization of Roll-up Operation')
fig_rollup.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4464980f-5910-4169-b198-12981b9f6af7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4464980f-5910-4169-b198-12981b9f6af7")) {                    Plotly.newPlot(                        "4464980f-5910-4169-b198-12981b9f6af7",                        [{"hovertemplate":"City=%{x}\u003cbr\u003ePrice=%{y}\u003cbr\u003eDelivery time=%{z}\u003cbr\u003eAvg ratings=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3.596513249651325,3.7628964059196615,3.776311030741411,3.5263502454991813,3.701395348837209,3.698811292719168,3.5993735317149564,3.5501834862385317,3.580078125],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":["Ahmedabad","Bangalore","Chennai","Delhi","Hyderabad","Kolkata","Mumbai","Pune","Surat"],"y":[318.12831241283124,382.52431289640595,356.24773960217,333.3011456628478,299.92651162790696,362.29420505200596,393.7948316366484,353.76330275229355,270.171875],"z":[44.709902370990235,50.52959830866808,58.96835443037975,50.734860883797054,49.93302325581395,67.80980683506687,48.31871574001566,55.85412844036697,48.484375],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"f ...

# %%
# Drill-down operation (detailed view at City and Area level)
drill_down_swiggy = swiggy_df.groupby(['City', 'Area']).agg({'Price': 'mean', 'Avg ratings': 'mean', 'Delivery time': 'mean'}).reset_index()
display("\nDrill-down operation result:\n", drill_down_swiggy)
# Out:
# '\nDrill-down operation result:\n'
#           City                  Area       Price  Avg ratings  Delivery time
# 0    Ahmedabad   Akhbar Nagar Circle  200.000000     2.900000      53.000000
# 1    Ahmedabad                 Acher  200.000000     3.700000      70.000000
# 2    Ahmedabad             Ahmedabad  344.444444     4.066667      43.222222
# 3    Ahmedabad              Ambavadi  200.000000     4.400000      39.000000
# 4    Ahmedabad              Ambawadi  302.000000     3.724000      38.560000
# ..         ...                   ...         ...          ...            ...
# 838      Surat                  Vesu  333.333333     3.695238      56.285714
# 839      Surat              Vip Road  220.000000     2.900000      49.000000
# 840      Surat          Vishal Nagar  228.333333     3.933333      57.000000
# 841      Surat          Yamuna Nagar  250.000000     3.233333      39.333333
# 842      Surat     Yoginagar Society  200.000000     3.900000      55.000000
#
# [843 rows x 5 columns]

# %%
# 3D scatter plot to visualize the drill-down data
fig_drilldown = px.scatter_3d(drill_down_swiggy, x='Area', y='Price', z='Delivery time', color='Avg ratings', title='3D Visualization of Drill-down Operation')
fig_drilldown.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="edffab40-f7d6-46e0-8a5e-ecdebc6585d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
25,3.966666666666667,2.9,4.3,2.9,3.8,2.9,4.0,4.1,3.483333333333333,2.9,3.6,3.34375,4.2,2.9,3.5258064516129033,2.9,3.6,3.7083333333333335,2.9,3.6166666666666667,2.9,3.6,4.057142857142857,2.7,3.621428571428571,3.894117647058824,4.2,3.8499999999999996,4.2,4.3,3.3817120622568093,2.9,2.9,4.2,2.9,2.9,3.7,2.9,2.9,3.75,3.733333333333333,3.325,4.0,3.966666666666667,3.95,4.0,3.85,2.9,3.78,2.9,3.8,2.9,2.9,3.75,4.005263157894737,3.9,2.9,2.9,3.745454545454545,3.91,2.8,3.9666666666666663,4.3,4.2,4.2,3.4833333333333334,3.7714285714285714,2.9,3.6,4.8,4.0,3.425,4.1,2.9,3.55,3.965217391304348,3.775,4.15,3.7285714285714286,3.8,3.6,3.875,3.621212121212121,2.9,3.7,4.2,3.692920353982301,2.9,4.05,4.1,3.6333333333333333,2.9,4.0,4.4,3.3,3.7,4.3,4.1,3.8,3.6,3.352,4.0,4.0,4.1,4.1,4.041176470588235,4.0,3.825,2.9,3.95,4.14,4.15,3.4,4.05,4.05,3.6,3.5,4.0285714285714285,3.9,2.9,3.467391304347826,3.97962962962963,3.7 ...

# %%
# Slice operation (filtering data for a specific City)
slice_op_swiggy = swiggy_df[swiggy_df['City'] == 'Bangalore']
display("\nSlice operation result:\n", slice_op_swiggy)
# Out:
# '\nSlice operation result:\n'
#           ID                       Area       City         Restaurant  Price  \
# 0        211                Koramangala  Bangalore        Tandoor Hut  300.0
# 1        221                Koramangala  Bangalore      Tunday Kababi  300.0
# 2        246                  Jogupalya  Bangalore            Kim Lee  650.0
# 3        248                Indiranagar  Bangalore  New Punjabi Hotel  250.0
# 4        249                Indiranagar  Bangalore                Nh8  350.0
# ...      ...                        ...        ...                ...    ...
# 8626  455120                   Majestic  Bangalore      Mejestic Cafe  250.0
# 8647  457452  Sanjay Nagar New Bel Road  Bangalore   Sri Ramji Sweets   75.0
# 8648  457630                  Jayanagar  Bangalore      Sri Sai Foods  149.0
# 8664  461164                   Majestic  Bangalore  Himadri Ice Cream  250.0
# 8669  462943          Central Bangalore  Bangalore    Bangarpet Chats  110.0
#
#       Avg ratings  Total ratings  \
# 0             4.4            100
# 1             4.1            100
# 2             4.4            100
# 3             3.9            500
# 4             4.0             50
# ...           ...            ...
# 8626          2.9             80
# 8647          2.9             80
# 8648          2.9             80
# 8664          2.9             80
# 8669          2.9             80
#
#                                               Food type  \
# 0             Biryani,Chinese,North Indian,South Indian
# 1                                      Mughlai,Lucknowi
# 2                                               Chinese
# 3                  North Indian,Punjabi,Tandoor,Chinese
# 4     Rajasthani,Gujarati,North Indian,Snacks,Desser...
# ...                                                 ...
# 8626              South Indian,Indian,Chinese,Beverages
# 8647                                             Sweets
# 8648                                       South Indian
# 8664                       Ice Cream,Beverages,Desserts
# 8669                                              Chaat
#
#                         Address  Delivery time
# 0                     5Th Block             59
# 1                     5Th Block             56
# 2                   Double Road             50
# 3                  80 Feet Road             57
# 4                  80 Feet Road             63
# ...                         ...            ...
# 8626                   Majestic             51
# 8647  Sanjay Nagar New Bel Road             51
# 8648                  Jayanagar             56
# 8664                   Majestic             40
# 8669          Central Bangalore             37
#
# [946 rows x 10 columns]

# %%
# 3D scatter plot to visualize the slice data
fig_slice = px.scatter_3d(slice_op_swiggy, x='Price', y='Avg ratings', z='Delivery time', color='Restaurant', title='3D Visualization of Slice Operation')
fig_slice.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2dbb9a8d-19af-4711-a233-4d4584f73e99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dbb9a8d-19af-4711-a233-4d4584f73e99")) {                    Plotly.newPlot(                        "2dbb9a8d-19af-4711-a233-4d4584f73e99",                        [{"hovertemplate":"Restaurant=Tandoor Hut\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tandoor Hut","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Tandoor Hut","scene":"scene","showlegend":true,"x":[300.0],"y":[4.4],"z":[59],"type":"scatter3d"},{"hovertemplate":"Restaurant=Tunday Kababi\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tunday Kababi","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Tunday Kababi","scene":"scene","showlegend":true,"x":[300.0],"y":[4.1],"z":[56],"type":"scatter3d"},{"hovertemplate":"Restaurant=Kim Lee\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kim Lee","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Kim Lee","scene":"scene","showlegend":true,"x":[650.0],"y":[4.4],"z":[50],"type":"scatter3d"},{"hovertemplate":"Restaurant=New Punjabi Hotel\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"New Punjabi Hotel","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"New Punjabi Hotel","scene":"scene","showlegend":true,"x":[250.0],"y":[3.9],"z":[57],"type":"scatter3d"},{"hovertemplate":"Restaurant=Nh8\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nh8","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Nh8","scene":"scene","showlegend":true,"x":[350.0],"y":[4.0],"z":[63],"type":"scatter3d"},{"hovertemplate":"Restaurant=Treat\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Treat","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Treat","scene":"scene","showlegend":true,"x":[800.0],"y":[4.5],"z":[56],"type":"scatter3d"},{"hovertemplate":"Restaurant=Chinita Real Mexican Food\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chinita Real Mexican Food","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Chinita Real Mexican Food","scene":"scene","showlegend":true,"x":[1000.0],"y":[4.5],"z":[53],"type":"scatter3d"},{"hovertemplate":"Restaurant=Cupcake Noggins - Cakespastries And Desserts\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cupcake Noggins - Cakespastries And Desserts","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Cupcake Noggins - Cakespastries And Desserts","scene":"scene","showlegend":true,"x":[150.0],"y":[4.3],"z":[57],"type":"scatter3d"},{"hovertemplate":"Restaurant=Tea Brew\u003cbr\u003ePrice=%{x}\u003cbr\u003eAvg ratings=%{y}\u003cbr\u003eDelivery time=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tea Brew","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Tea Brew","scene":"scene","showlegend":true,"x":[350.0],"y":[4.1],"z":[57],"type":"scatter3d"},{"hovertemplate":"Restaurant=Bangaliana ...

# %%
# Dice operation (filtering data for specific Cities and Areas)
dice_op_swiggy = swiggy_df[(swiggy_df['City'].isin(['Bangalore', 'Mumbai'])) & (swiggy_df['Area'].isin(['Koramangala', 'Indiranagar']))]
display("\nDice operation result:\n", dice_op_swiggy)
# Out:
# '\nDice operation result:\n'
#           ID         Area       City              Restaurant  Price  \
# 0        211  Koramangala  Bangalore             Tandoor Hut  300.0
# 1        221  Koramangala  Bangalore           Tunday Kababi  300.0
# 3        248  Indiranagar  Bangalore       New Punjabi Hotel  250.0
# 4        249  Indiranagar  Bangalore                     Nh8  350.0
# 5        254  Indiranagar  Bangalore                   Treat  800.0
# ...      ...          ...        ...                     ...    ...
# 8336  412597  Indiranagar  Bangalore            Babaji Bites  250.0
# 8452  434665  Indiranagar  Bangalore             Idc Kitchen  200.0
# 8506  442032  Koramangala  Bangalore  Keventers Ice Creamery  200.0
# 8581  451110  Indiranagar  Bangalore                3 Mangos  100.0
# 8600  452240  Koramangala  Bangalore             Chaat House  200.0
#
#       Avg ratings  Total ratings  \
# 0             4.4            100
# 1             4.1            100
# 3             3.9            500
# 4             4.0             50
# 5             4.5            100
# ...           ...            ...
# 8336          2.9             80
# 8452          4.2            100
# 8506          4.9             20
# 8581          2.9             80
# 8600          2.9             80
#
#                                               Food type        Address  \
# 0             Biryani,Chinese,North Indian,South Indian      5Th Block
# 1                                      Mughlai,Lucknowi      5Th Block
# 3                  North Indian,Punjabi,Tandoor,Chinese   80 Feet Road
# 4     Rajasthani,Gujarati,North Indian,Snacks,Desser...   80 Feet Road
# 5                                  Mughlai,North Indian  100 Feet Road
# ...                                                 ...            ...
# 8336                                    Chinese,Tandoor    Indiranagar
# 8452                      South Indian,Beverages,Snacks    Indiranagar
# 8506                                 Ice Cream,Desserts      7Th Block
# 8581                                Beverages,Ice Cream    Indiranagar
# 8600            Beverages,Ice Cream,North Indian,Snacks    Koramangala
#
#       Delivery time
# 0                59
# 1                56
# 3                57
# 4                63
# 5                56
# ...             ...
# 8336             59
# 8452             53
# 8506             57
# 8581             56
# 8600             59
#
# [254 rows x 10 columns]

# %%
# 3D scatter plot to visualize the dice data
fig_dice = px.scatter_3d(dice_op_swiggy, x='Area', y='Price', z='Delivery time', color='Avg ratings', title='3D Visualization of Dice Operation')
fig_dice.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4aff2ed4-8156-417e-a979-4930821bf747" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4aff2ed4-8156-417e-a979-4930821bf747")) {                    Plotly.newPlot(                        "4aff2ed4-8156-417e-a979-4930821bf747",                        [{"hovertemplate":"Area=%{x}\u003cbr\u003ePrice=%{y}\u003cbr\u003eDelivery time=%{z}\u003cbr\u003eAvg ratings=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[
Indiranagar","Indiranagar","Indiranagar","Indiranagar","Indiranagar","Indiranagar","Koramangala","Koramangala","Indiranagar","Koramangala","Koramangala","Koramangala","Indiranagar","Indira ...

# %%
# Pivot operation (reshaping data to view average ratings by City and Food type)
pivot_op_swiggy = swiggy_df.pivot_table(values='Avg ratings', index='City', columns='Food type', aggfunc=np.mean).reset_index()
display("\nPivot operation result:\n", pivot_op_swiggy)
# Out:
# '\nPivot operation result:\n'
# Food type       City  Afghani,Arabian,Indian,Tandoor  Afghani,Biryani  \
# 0          Ahmedabad                             NaN              NaN
# 1          Bangalore                             NaN              NaN
# 2            Chennai                             NaN              4.3
# 3              Delhi                             NaN              NaN
# 4          Hyderabad                             4.3              NaN
# 5            Kolkata                             NaN              NaN
# 6             Mumbai                             NaN              NaN
# 7               Pune                             NaN              NaN
# 8              Surat                             NaN              NaN
#
# Food type  Afghani,Mughlai  American  American  Beverages  Fast Food  \
# 0                      NaN  2.900000                             NaN
# 1                      NaN       NaN                             NaN
# 2                      NaN  4.400000                             NaN
# 3                      NaN  4.200000                             NaN
# 4                      NaN  4.500000                             NaN
# 5                      2.9  4.500000                             NaN
# 6                      NaN  4.185714                             4.3
# 7                      NaN       NaN                             NaN
# 8                      NaN       NaN                             NaN
#
# Food type  American  Chinese  Continental  Desserts  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               4.3
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
#
# Food type  American  Chinese  Indian  American  Continental  \
# 0                                NaN                    NaN
# 1                                NaN                    NaN
# 2                                NaN                    NaN
# 3                                NaN                    NaN
# 4                                NaN                    NaN
# 5                                NaN                    NaN
# 6                                2.9                    4.5
# 7                                NaN                    NaN
# 8                                NaN                    NaN
#
# Food type  American  Continental  Italian  Pastas  Snacks  Desserts  Beverages  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# 5                                                        4.3
# 6                                                        NaN
# 7                                                        NaN
# 8                                                        NaN
#
# Food type  ...  Tibetan,Chinese,Indian  \
# 0          ...                     4.3
# 1          ...                     NaN
# 2          ...                     NaN
# 3          ...                     NaN
# 4          ...                     NaN
# 5          ...                     NaN
# 6          ...                     NaN
# 7          ...                     NaN
# 8          ...                     NaN
#
# Food type  Tibetan,Fast Food,Chinese,Asian,Snacks,Continental,Desserts,Beverages  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        3.5
# 4                                                        3.9
# 5                                                        4.0
# 6                                                        4.0
# 7                                                        3.9
# 8                                                        NaN
#
# Food type  Tibetan,Fast Food,Healthy Food,Asian,Chinese,Snacks,Continental,Desserts,Beverages  \
# 0                                                        NaN
# 1                                                        4.3
# 2                                                        4.2
# 3                                                        3.8
# 4                                                        NaN
# 5                                                        NaN
# 6                                                        NaN
# 7                                                        NaN
# 8                                                        NaN
#
# Food type  Tibetan,Healthy Food,Asian,Chinese,Snacks,Continental,Desserts,Beverages  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# 5                                                        4.3
# 6                                                        4.0
# 7                                                        NaN
# 8                                                        NaN
#
# Food type  Tibetan,Italian,Mughlai,Chinese,Kerala  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             4.0
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
#
# Food type  Tibetan,Lebanese,Fast Food,Tandoor  Tribal,Seafood,Chinese  \
# 0                                         NaN                     NaN
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 3                                         NaN                     NaN
# 4                                         NaN                     NaN
# 5                                         NaN                     4.3
# 6                                         4.2                     NaN
# 7                                         NaN                     NaN
# 8                                         NaN                     NaN
#
# Food type  Turkish  Turkish,Arabian  \
# 0              NaN              NaN
# 1              2.9              2.9
# 2              NaN              NaN
# 3              NaN              NaN
# 4              2.8              3.5
# 5              NaN              NaN
# 6              2.9              NaN
# 7              NaN              NaN
# 8              NaN              NaN
#
# Food type  Turkish,Mediterranean,Middle Eastern,Lebanese,Arabian
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# 5                                                        NaN
# 6                                                        4.1
# 7                                                        NaN
# 8                                                        NaN
#
# [9 rows x 3735 columns]

# %%
# 3D scatter plot to visualize the pivot data
fig_pivot = px.scatter_3d(pivot_op_swiggy, x='City', y='North Indian', z='South Indian', color='City', title='3D Visualization of Pivot Operation')
fig_pivot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3f717bac-e28a-4c3f-aa8a-9abec488987e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f717bac-e28a-4c3f-aa8a-9abec488987e")) {                    Plotly.newPlot(                        "3f717bac-e28a-4c3f-aa8a-9abec488987e",                        [{"hovertemplate":"City=%{x}\u003cbr\u003eNorth Indian=%{y}\u003cbr\u003eSouth Indian=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ahmedabad","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Ahmedabad","scene":"scene","showlegend":true,"x":["Ahmedabad"],"y":[3.6300000000000003],"z":[3.792307692307692],"type":"scatter3d"},{"hovertemplate":"City=%{x}\u003cbr\u003eNorth Indian=%{y}\u003cbr\u003eSouth Indian=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bangalore","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Bangalore","scene":"scene","showlegend":true,"x":["Bangalore"],"y":[3.512],"z":[4.034375],"type":"scatter3d"},{"hovertemplate":"City=%{x}\u003cbr\u003eNorth Indian=%{y}\u003cbr\u003eSouth Indian=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chennai","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Chennai","scene":"scene","showlegend":true,"x":["Chennai"],"y":[3.84375],"z":[3.9081632653061225],"type":"scatter3d"},{"hovertemplate":"City=%{x}\u003cbr\u003eNorth Indian=%{y}\u003cbr\u003eSouth Indian=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Delhi","scene":"scene","showlegend":true,"x":["Delhi"],"y":[3.3978723404255318],"z":[3.6333333333333333],"type":"scatter3d"},{"hovertemplate":"City=%{x}\u003cbr\u003eNorth Indian=%{y}\u003cbr\u003eSouth Indian=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hyderabad","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Hyderabad","scene":"scene","showlegend":true,"x":["Hyderabad"],"y":[3.611111111111111],"z":[3.8763157894736837],"type":"scatter3d"},{"hovertemplate":"City=%{x}\u003cbr\u003eNorth Indian=%{y}\u003cbr\u003eSouth Indian=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kolkata","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Kolkata","scene":"scene","showlegend":true,"x":["Kolkata"],"y":[3.630434782608696],"z":[3.954166666666667],"type":"scatter3d"},{"hovertemplate":"City=%{x}\u003cbr\u003eNorth Indian=%{y}\u003cbr\u003eSouth Indian=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mumbai","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Mumbai","scene":"scene","showlegend":true,"x":["Mumbai"],"y":[3.6448275862068966],"z":[3.423076923076923],"type":"scatter3d"},{"hovertemplate":"City=%{x}\u003cbr\u003eNorth Indian=%{y}\u003cbr\u003eSouth Indian=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pune","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Pune","scene":"scene","showlegend":true,"x":["Pune"],"y":[3.5450000000000004],"z":[3.7222222222222223],"type":"scatter3d"},{"hovertemplate":"City=%{x}\u003cbr\u003eNorth Indian=%{y}\u003cbr\u003eSouth Indian=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surat","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Surat","scene":"scene","showlegend":true,"x":["Surat"],"y":[3.5944444444444446],"z":[3.611111111111111],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444444 ...
